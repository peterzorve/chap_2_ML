# %% [markdown]
# ## Imports

# %%
# pip install --upgrade scikit-learn

# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sb
import matplotlib.pyplot as plt
import sklearn  as skl

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline

print("Pandas  ", pd.__version__)
print("Sklearn ", skl.__version__) # Try to use 0.24
# Out:
# Pandas   1.3.5
# Sklearn  1.0.2

# %% [markdown]
# ## Get the dataset
# - **CLOUD = True**: Download dataset from Kaggle. Necesary for cloud enviroments like COLAB. **Specify your [kaggle credentials](https://www.kaggle.com/docs/api)**.
# - **CLOUD = False**: Get the dataset from your local machine. **Specify the data path**.

# %%
# DATA_PATH = "../../Datasets/Tabular/titanic/"

# %% [markdown]
# ## Load data

# %%
" I Inserted this CELL "

df      = pd.read_csv("train.csv", index_col='PassengerId')
df_test = pd.read_csv("test.csv",  index_col='PassengerId')

print("Train DataFrame:", df.shape)
print("Test DataFrame: ", df_test.shape)
# Out:
# Train DataFrame: (891, 11)
# Test DataFrame:  (418, 11)

# %%
# df      = pd.read_csv(DATA_PATH + "train.csv", index_col='PassengerId')
# df_test = pd.read_csv(DATA_PATH + "test.csv",  index_col='PassengerId')

# print("Train DataFrame:", df.shape)
# print("Test DataFrame: ", df_test.shape)

# %% [markdown]
# ## Check missings

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
""" I inserted this CELL """
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# # Exercise 1 (2pts):
# Extract the title (Mr, Mrs, ... ) from the "Name" column.
#
# Tips:
# - split(',')[1] to get the 2nd part, and remove the surnamename
# - split('.')[0] to get the 1str part, and remove the name

# %%
""" I inserted this CELL """

df      = pd.read_csv("train.csv", index_col='PassengerId')
df_test = pd.read_csv("test.csv",  index_col='PassengerId')


df['Title']       = df['Name'].astype(str).apply(lambda x : x.split(',')[1].split('.')[0].strip())
df_test['Title']  = df_test['Name'].astype(str).apply(lambda x : x.split(',')[1].split('.')[0].strip())
df_test
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
#                 Sex   Age  SibSp  Parch              Ticket      Fare Cabin  \
# PassengerId
# 892            male  34.5      0      0              330911    7.8292   NaN
# 893          female  47.0      1      0              363272    7.0000   NaN
# 894            male  62.0      0      0              240276    9.6875   NaN
# 895            male  27.0      0      0              315154    8.6625   NaN
# 896          female  22.0      1      1             3101298   12.2875   NaN
# ...             ...   ...    ...    ...                 ...       ...   ...
# 1305           male   NaN      0      0           A.5. 3236    8.0500   NaN
# 1306         female  39.0      0      0            PC 17758  108.9000  C105
# 1307           male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 1308           male   NaN      0      0              359309    8.0500   NaN
# 1309           male   NaN      1      1                2668   22.3583   NaN
#
#             Embarked   Title
# PassengerId
# 892                Q      Mr
# 893                S     Mrs
# 894                Q      Mr
# 895                S      Mr
# 896                S     Mrs
# ...              ...     ...
# 1305               S      Mr
# 1306               C    Dona
# 1307               S      Mr
# 1308               S      Mr
# 1309               C  Master
#
# [418 rows x 12 columns]

# %%
# CODE HERE get_Title_from_Name funtion
# Create this function using lambda (not def)

#get_Title_from_Name = None

df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
assert df['Title'].values[0] == "Mr"
assert df['Title'].values[1] == "Mrs"
assert df['Title'].values[2] == "Miss"

assert df_test['Title'].values[0] == "Mr"
assert df_test['Title'].values[1] == "Mrs"
assert df_test['Title'].values[414] == "Dona"

# %% [markdown]
# # Exercise 2 (1pts):
# Apply the title_dictionary to get a better information about the title. You have to overwrite the Title variable.

# %%
title_dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir" : "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "the Countess":"Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr" : "Mr",
    "Mrs" : "Mrs",
    "Miss" : "Miss",
    "Master" : "Master",
    "Lady" : "Royalty"
}

# %%
# Use map to apply the prevous dict

# df['Title'].map(title_dictionary)

# df_test["Title"].map(title_dictionary)


df["Title"] =  df["Title"].map(title_dictionary)
df_test["Title"] = df_test['Title'].map(title_dictionary)

# %%
assert df['Title'].values[886] == "Officer"
assert df_test['Title'].values[417] == "Master"

# %% [markdown]
# # Exercise OPTINAL (0pts):
# Try to extract some information from the feature **Ticket**. Search on Internet if that colum has some kind of information.

# %% [markdown]
# # Exercise OPTIONAL (0pts):
# Try to extract some information from the feature **Cabin**. Search on Internet if that colum has some kind of information.

# %% [markdown]
# # Preprocessing
# For X data, notice that...
# - We drop Survived because is the target variable
# - We drop Name because we have extracted the Title: Mr, Mrs, ...
# - We drop Ticket because it has no information -> see df.Ticket.nunique()
# - We drop Cabin because it has a lot of missings (77% are missings)
#
# Then, we identify **numerical** variables and **categorical** variables,

# %%
x = df.drop(columns=["Survived", 'Name', 'Ticket', 'Cabin']) # X DATA (WILL BE TRAIN+VALID DATA)
y = df["Survived"] # 0 = No, 1 = Yes

x_test = df_test.drop(columns=['Name', 'Ticket', 'Cabin']) # # X_TEST DATA (NEW DATA)
x
# Out:
#              Pclass     Sex   Age  SibSp  Parch     Fare Embarked    Title
# PassengerId
# 1                 3    male  22.0      1      0   7.2500        S       Mr
# 2                 1  female  38.0      1      0  71.2833        C      Mrs
# 3                 3  female  26.0      0      0   7.9250        S     Miss
# 4                 1  female  35.0      1      0  53.1000        S      Mrs
# 5                 3    male  35.0      0      0   8.0500        S       Mr
# ...             ...     ...   ...    ...    ...      ...      ...      ...
# 887               2    male  27.0      0      0  13.0000        S  Officer
# 888               1  female  19.0      0      0  30.0000        S     Miss
# 889               3  female   NaN      1      2  23.4500        S     Miss
# 890               1    male  26.0      0      0  30.0000        C       Mr
# 891               3    male  32.0      0      0   7.7500        Q       Mr
#
# [891 rows x 8 columns]

# %%
cat_vars  = ['Sex', 'Embarked', 'Title']         # x.select_dtypes(include=[object]).columns.values.tolist()
num_vars  = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age'] # x.select_dtypes(exclude=[object]).columns.values.tolist()

# print("\nNumerical features:\n", num_vars)
# print("\nCategorical features:\n", cat_vars)

# %% [markdown]
# # Exercise 3 (2pts):
# Create a **ColumnTransformer for Tree Models**. You need to create 2 pipelines (one for numerical and other for categories). Remember:
# - Categorical pipeline: Some SimpleImputer -> Some Encoder
# - Numerical pipeline: Some SimpleImputer -> NO Encoder

# %%
""" I inserted this cell  """

from sklearn.svm import SVC 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split


# pipe1 = Pipeline( [  ('impute', SimpleImputer()) ] )

cat_vars  = ['Sex', 'Embarked', 'Title']         # x.select_dtypes(include=[object]).columns.values.tolist()
num_vars  = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age'] 


num_preprocessing = pipeline.Pipeline(steps=[ ('simple', SimpleImputer(missing_values=np.nan, strategy='mean'))  ])  # Some SimpleImputer here
cat_preporcessing = pipeline.Pipeline(steps=[ ('simple', SimpleImputer(missing_values=np.nan, strategy='constant')), ('ordinal', OrdinalEncoder(handle_unknown = 'use_encoded_value', unknown_value = -1) ) ] )

# num_preprocessing = pipeline.Pipeline(steps=[ ('simple', SimpleImputer())  ])  # Some SimpleImputer here
# cat_preporcessing = pipeline.Pipeline(steps=[ ('simple', SimpleImputer()), ('ordinal', OrdinalEncoder(handle_unknown = 'use encoded values', unknown_value = -1) ) ] )

  # Some SimpleImputer here
  # Some Encoder here. Remember to handle_unknown

tree_prepro = compose.ColumnTransformer(transformers=[  ('num', num_preprocessing, num_vars), 
                                                        ('cat', cat_preporcessing, cat_vars), ], 
                                                        remainder='drop')                         # Drop other vars not specified in num_vars or cat_vars

tree_prepro


### BEGIN SOLUTION
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simple', SimpleImputer())]),
#                                  ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age']),
#                                 ('cat',
#                                  Pipeline(steps=[('simple',
#                                                   SimpleImputer(strategy='constant')),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  ['Sex', 'Embarked', 'Title'])])

# %%
assert type(tree_prepro)      is compose._column_transformer.ColumnTransformer
assert type(num_preprocessing) is pipeline.Pipeline
assert type(cat_preporcessing) is pipeline.Pipeline
assert len(num_preprocessing) == 1
assert len(cat_preporcessing) == 2

# %% [markdown]
# # Exercise 4 (1pts):
# 1. Complete the diccionary with some Tree Models.
# 2. Then we put each model in a Pipeline where:
#    - first is the prepocessing with the column Transformer
#    - Then is the Tree model
# 3. Display the fullpipeline of the LGBMClassifier

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier

# %%
tree_classifiers = {

  "Decision Tree" : DecisionTreeClassifier(),
  "Extra Trees"   : ExtraTreesClassifier(), 
  "Random Forest" : RandomForestClassifier(), 
  "AdaBoost"      : AdaBoostClassifier(), 
  "Skl GBM": GradientBoostingClassifier(), 
  "Skl HistGBM": HistGradientBoostingClassifier(), 
  "XGBoost": XGBClassifier(), 
  "LightGBM": LGBMClassifier(), 
  "CatBoost": CatBoostClassifier()

}
tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers['LightGBM']
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simple',
#                                                                    SimpleImputer())]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('simple',
#                                                                    SimpleImputer(strategy='constant')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('lgbmclassifier', LGBMClassifier())])

# %%
for pipe in tree_classifiers.values():
    assert type(pipe) is pipeline.Pipeline

# %% [markdown]
# # Exercise 5 (3pts):
# Define a simple split validation strategy with:
# - 80% for train
# - 20% for validation
# - With stratification
# - random_state=0
#
# And train all the models in a for loop

# %%
"""
x_train, x_val, y_train, y_val = model_selection.train_test_split(
    # CODE HERE
)
"""
x_train, x_val, y_train, y_val = model_selection.train_test_split(x, y, test_size=0.2, random_state=0, stratify= y)

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():

    start_time = time.time()

    model.fit(x_train, y_train)
    
    # FOR EVERY PIPELINE (PREPRO + MODEL) -> TRAIN WITH TRAIN DATA (x_train)
    
    # GET PREDICTIONS USING x_val

    pred = model.predict(x_val) # CODE HERE

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                                                          
### BEGIN SOLUTION

results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\Omistaja\.conda\envs\pz\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:14:40] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.008911
# 0:	learn: 0.6896726	total: 155ms	remaining: 2m 34s
# 1:	learn: 0.6840036	total: 160ms	remaining: 1m 20s
# 2:	learn: 0.6784911	total: 165ms	remaining: 54.7s
# 3:	learn: 0.6726585	total: 168ms	remaining: 41.9s
# 4:	learn: 0.6659867	total: 175ms	remaining: 34.9s
# 5:	learn: 0.6602370	total: 193ms	remaining: 32s
# 6:	learn: 0.6544571	total: 199ms	remaining: 28.2s
# 7:	learn: 0.6500395	total: 202ms	remaining: 25.1s
# 844:	learn: 0.2818885	total: 9.8s	remaining: 1.8s
# 845:	learn: 0.2816678	total: 9.8s	remaining: 1.78s
# 846:	learn: 0.2816387	total: 9.81s	remaining: 1.77s
# 847:	learn: 0.2815538	total: 9.82s	remaining: 1.76s
# 848:	learn: 0.2814462	total: 9.84s	remaining: 1.75s
# 849:	learn: 0.2812809	total: 9.85s	remaining: 1.74s
# 850:	learn: 0.2811936	total: 9.86s	remaining: 1.73s
# 851:	learn: 0.2811375	total: 9.86s	remaining: 1.71s
# 852:	learn: 0.2810628	total: 9.87s	remaining: 1.7s
# 853:	learn: 0.2809994	total: 9.88s	remaining: 1.69s
# 854:	learn: 0.2809792	total: 9.88s	remaining: 1.68s
# 855:	learn: 0.2807926	total: 9.88s	remaining: 1.66s
# 856:	learn: 0.2806750	total: 9.89s	remaining: 1.65s
# 857:	learn: 0.2806581	total: 9.9s	remaining: 1.64s
# 858:	learn: 0.2804239	total: 9.92s	remaining: 1.63s
# 859:	learn: 0.2803880	total: 9.93s	remaining: 1.62s
# 860:	learn: 0.2802896	total: 9.93s	remaining: 1.6s
# 861:	learn: 0.2802179	total: 9.96s	remaining: 1.59s
# 862:	learn: 0.2801967	total: 9.97s	remaining: 1.58s
# 863:	learn: 0.2800584	total: 9.98s	remaining: 1.57s
# 864:	learn: 0.2798849	total: 9.99s	remaining: 1.56s
# 865:	learn: 0.2798245	total: 10s	remaining: 1.55s
# 866:	learn: 0.2797786	total: 10s	remaining: 1.54s
# 867:	learn: 0.2796540	total: 10s	remaining: 1.52s
# 868:	learn: 0.2794859	total: 10s	remaining: 1.51s
# 869:	learn: 0.2794344	total: 10s	remaining: 1.5s
# 870:	learn: 0.2793640	total: 10.1s	remaining: 1.49s
# 871:	learn: 0.2793505	total: 10.1s	remaining: 1.48s
# 872:	learn: 0.2792764	total: 10.1s	remaining: 1.46s
# 873:	learn: 0.2792092	total: 10.1s	remaining: 1.45s
# 874:	learn: 0.2791498	total: 10.1s	remaining: 1.44s
# 875:	learn: 0.2789863	total: 10.1s	remaining: 1.43s
# 876:	learn: 0.2787122	total: 10.1s	remaining: 1.42s
# 877:	learn: 0.2786045	total: 10.1s	remaining: 1.4s
# 878:	learn: 0.2784975	total: 10.1s	remaining: 1.39s
# 879:	learn: 0.2784471	total: 10.1s	remaining: 1.38s
# 880:	learn: 0.2783795	total: 10.1s	remaining: 1.37s
# 881:	learn: 0.2782080	total: 10.1s	remaining: 1.36s
# 882:	learn: 0.2780853	total: 10.2s	remaining: 1.35s
# 883:	learn: 0.2779871	total: 10.2s	remaining: 1.34s
# 884:	learn: 0.2776883	total: 10.2s	remaining: 1.32s
# 885:	learn: 0.2776422	total: 10.2s	remaining: 1.31s
# 886:	learn: 0.2775287	total: 10.2s	remaining: 1.3s
# 887:	learn: 0.2773877	total: 10.2s	remaining: 1.29s
# 888:	learn: 0.2772960	total: 10.2s	remaining: 1.28s
# 889:	learn: 0.2772559	total: 10.2s	remaining: 1.27s
# 890:	learn: 0.2771133	total: 10.2s	remaining: 1.25s
# 891:	learn: 0.2769642	total: 10.3s	remaining: 1.24s
# 892:	learn: 0.2767066	total: 10.3s	remaining: 1.23s
# 893:	learn: 0.2766835	total: 10.3s	remaining: 1.22s
# 894:	learn: 0.2766375	total: 10.3s	remaining: 1.2s
# 895:	learn: 0.2765964	total: 10.3s	remaining: 1.19s
# 896:	learn: 0.2765175	total: 10.3s	remaining: 1.18s
# 897:	learn: 0.2764848	total: 10.3s	remaining: 1.17s
# 898:	learn: 0.2763671	total: 10.3s	remaining: 1.16s
# 899:	learn: 0.2762396	total: 10.3s	remaining: 1.15s
# 900:	learn: 0.2760035	total: 10.3s	remaining: 1.13s
# 901:	learn: 0.2759791	total: 10.3s	remaining: 1.12s
# 902:	learn: 0.2759291	total: 10.3s	remaining: 1.11s
# 903:	learn: 0.2758251	total: 10.3s	remaining: 1.1s
# 904:	learn: 0.2757313	total: 10.3s	remaining: 1.08s
# 905:	learn: 0.2756670	total: 10.3s	remaining: 1.07s
# 906:	learn: 0.2754596	total: 10.4s	remaining: 1.06s
# 907:	learn: 0.2754137	total: 10.4s	remaining: 1.05s
# 908:	learn: 0.2753380	total: 10.4s	remaining: 1.04s
# 909:	learn: 0.2752974	total: 10.4s	remaining: 1.03s
# 910:	learn: 0.2752713	total: 10.4s	remaining: 1.02s
# 911:	learn: 0.2751839	total: 10.5s	remaining: 1.01s
# 912:	learn: 0.2750569	total: 10.5s	remaining: 1s
# 913:	learn: 0.2749974	total: 10.5s	remaining: 988ms
# 914:	learn: 0.2749275	total: 10.5s	remaining: 976ms
# 915:	learn: 0.2748108	total: 10.5s	remaining: 964ms
# 916:	learn: 0.2747556	total: 10.5s	remaining: 952ms
# 917:	learn: 0.2747159	total: 10.5s	remaining: 940ms
# 918:	learn: 0.2747040	total: 10.5s	remaining: 928ms
# 919:	learn: 0.2745926	total: 10.5s	remaining: 916ms
# 920:	learn: 0.2745747	total: 10.5s	remaining: 904ms
# 921:	learn: 0.2745270	total: 10.5s	remaining: 892ms
# 922:	learn: 0.2744220	total: 10.6s	remaining: 882ms
# 923:	learn: 0.2742880	total: 10.6s	remaining: 870ms
# 924:	learn: 0.2741724	total: 10.6s	remaining: 858ms
# 925:	learn: 0.2741276	total: 10.6s	remaining: 846ms
# 926:	learn: 0.2740710	total: 10.6s	remaining: 834ms
# 927:	learn: 0.2738947	total: 10.6s	remaining: 822ms
# 928:	learn: 0.2738498	total: 10.6s	remaining: 810ms
# 929:	learn: 0.2738068	total: 10.6s	remaining: 798ms
# 930:	learn: 0.2735756	total: 10.6s	remaining: 786ms
# 931:	learn: 0.2735393	total: 10.6s	remaining: 776ms
# 932:	learn: 0.2734913	total: 10.6s	remaining: 764ms
# 933:	learn: 0.2734309	total: 10.6s	remaining: 752ms
# 934:	learn: 0.2733404	total: 10.7s	remaining: 740ms
# 935:	learn: 0.2731850	total: 10.7s	remaining: 729ms
# 936:	learn: 0.2731536	total: 10.7s	remaining: 717ms
# 937:	learn: 0.2730590	total: 10.7s	remaining: 706ms
# 986:	learn: 0.2678159	total: 11.1s	remaining: 147ms
# 987:	learn: 0.2677220	total: 11.1s	remaining: 135ms
# 988:	learn: 0.2676569	total: 11.1s	remaining: 124ms
# 989:	learn: 0.2676259	total: 11.2s	remaining: 113ms
# 990:	learn: 0.2674319	total: 11.2s	remaining: 101ms
# 991:	learn: 0.2673158	total: 11.2s	remaining: 90.2ms
# 992:	learn: 0.2672626	total: 11.2s	remaining: 79.2ms
# 993:	learn: 0.2671601	total: 11.2s	remaining: 67.8ms
# 994:	learn: 0.2670508	total: 11.2s	remaining: 56.5ms
# 995:	learn: 0.2667413	total: 11.2s	remaining: 45.2ms
# 996:	learn: 0.2666946	total: 11.2s	remaining: 33.8ms
# 997:	learn: 0.2665183	total: 11.3s	remaining: 22.5ms
# 998:	learn: 0.2664812	total: 11.3s	remaining: 11.3ms
# 999:	learn: 0.2662116	total: 11.3s	remaining: 0us
# <style type="text/css">
# #T_2d9bd_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 84.9%, transparent 84.9%);
# }
# #T_2d9bd_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.6%, transparent 82.6%);
# }
# #T_2d9bd_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.6%, transparent 81.6%);
# }
# #T_2d9bd_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
# }
# #T_2d9bd_row2_col1, #T_2d9bd_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.0%, transparent 81.0%);
# }
# #T_2d9bd_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.6%, transparent 78.6%);
# }
# #T_2d9bd_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.3%, transparent 78.3%);
# }
# #T_2d9bd_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
# }
# #T_2d9bd_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.0%, transparent 78.0%);
# }
# #T_2d9bd_row5_col1, #T_2d9bd_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.3%, transparent 79.3%);
# }
# #T_2d9bd_row5_col2, #T_2d9bd_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.0%, transparent 77.0%);
# }
# #T_2d9bd_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.1%, transparent 77.1%);
# }
# #T_2d9bd_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 75.4%, transparent 75.4%);
# }
# #T_2d9bd_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 76.0%, transparent 76.0%);
# }
# #T_2d9bd_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 73.4%, transparent 73.4%);
# }
# </style>
# <table id="T_2d9bd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d9bd_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2d9bd_row0_col0" class="data row0 col0" >Skl GBM</td>
#       <td id="T_2d9bd_row0_col1" class="data row0 col1" >84.916201</td>
#       <td id="T_2d9bd_row0_col2" class="data row0 col2" >82.595520</td>
#       <td id="T_2d9bd_row0_col3" class="data row0 col3" >1.040398</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2d9bd_row1_col0" class="data row1 col0" >XGBoost</td>
#       <td id="T_2d9bd_row1_col1" class="data row1 col1" >81.564246</td>
#       <td id="T_2d9bd_row1_col2" class="data row1 col2" >78.787879</td>
#       <td id="T_2d9bd_row1_col3" class="data row1 col3" >0.658573</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2d9bd_row2_col0" class="data row2 col0" >Skl HistGBM</td>
#       <td id="T_2d9bd_row2_col1" class="data row2 col1" >81.005587</td>
#       <td id="T_2d9bd_row2_col2" class="data row2 col2" >78.603426</td>
#       <td id="T_2d9bd_row2_col3" class="data row2 col3" >3.053676</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2d9bd_row3_col0" class="data row3 col0" >LightGBM</td>
#       <td id="T_2d9bd_row3_col1" class="data row3 col1" >81.005587</td>
#       <td id="T_2d9bd_row3_col2" class="data row3 col2" >78.333333</td>
#       <td id="T_2d9bd_row3_col3" class="data row3 col3" >0.870609</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2d9bd_row4_col0" class="data row4 col0" >AdaBoost</td>
#       <td id="T_2d9bd_row4_col1" class="data row4 col1" >79.888268</td>
#       <td id="T_2d9bd_row4_col2" class="data row4 col2" >77.964427</td>
#       <td id="T_2d9bd_row4_col3" class="data row4 col3" >0.807148</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2d9bd_row5_col0" class="data row5 col0" >Random Forest</td>
#       <td id="T_2d9bd_row5_col1" class="data row5 col1" >79.329609</td>
#       <td id="T_2d9bd_row5_col2" class="data row5 col2" >76.969697</td>
#       <td id="T_2d9bd_row5_col3" class="data row5 col3" >1.000699</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2d9bd_row6_col0" class="data row6 col0" >CatBoost</td>
#       <td id="T_2d9bd_row6_col1" class="data row6 col1" >79.329609</td>
#       <td id="T_2d9bd_row6_col2" class="data row6 col2" >76.969697</td>
#       <td id="T_2d9bd_row6_col3" class="data row6 col3" >13.586568</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_2d9bd_row7_col0" class="data row7 col0" >Decision Tree</td>
#       <td id="T_2d9bd_row7_col1" class="data row7 col1" >77.094972</td>
#       <td id="T_2d9bd_row7_col2" class="data row7 col2" >75.421607</td>
#       <td id="T_2d9bd_row7_col3" class="data row7 col3" >0.212057</td>
#     </tr>
#     <tr>
#       <th id="T_2d9bd_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_2d9bd_row8_col0" class="data row8 col0" >Extra Trees</td>
#       <td id="T_2d9bd_row8_col1" class="data row8 col1" >75.977654</td>
#       <td id="T_2d9bd_row8_col2" class="data row8 col2" >73.432148</td>
#       <td id="T_2d9bd_row8_col3" class="data row8 col3" >0.693111</td>
#     </tr>
#   </tbody>
# </table>

# %%
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# <style type="text/css">
# #T_10b71_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 84.9%, transparent 84.9%);
# }
# #T_10b71_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.6%, transparent 82.6%);
# }
# #T_10b71_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.6%, transparent 81.6%);
# }
# #T_10b71_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
# }
# #T_10b71_row2_col1, #T_10b71_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.0%, transparent 81.0%);
# }
# #T_10b71_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.6%, transparent 78.6%);
# }
# #T_10b71_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.3%, transparent 78.3%);
# }
# #T_10b71_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
# }
# #T_10b71_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.0%, transparent 78.0%);
# }
# #T_10b71_row5_col1, #T_10b71_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.3%, transparent 79.3%);
# }
# #T_10b71_row5_col2, #T_10b71_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.0%, transparent 77.0%);
# }
# #T_10b71_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.1%, transparent 77.1%);
# }
# #T_10b71_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 75.4%, transparent 75.4%);
# }
# #T_10b71_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 76.0%, transparent 76.0%);
# }
# #T_10b71_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 73.4%, transparent 73.4%);
# }
# </style>
# <table id="T_10b71_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10b71_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_10b71_row0_col0" class="data row0 col0" >Skl GBM</td>
#       <td id="T_10b71_row0_col1" class="data row0 col1" >84.916201</td>
#       <td id="T_10b71_row0_col2" class="data row0 col2" >82.595520</td>
#       <td id="T_10b71_row0_col3" class="data row0 col3" >1.040398</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_10b71_row1_col0" class="data row1 col0" >XGBoost</td>
#       <td id="T_10b71_row1_col1" class="data row1 col1" >81.564246</td>
#       <td id="T_10b71_row1_col2" class="data row1 col2" >78.787879</td>
#       <td id="T_10b71_row1_col3" class="data row1 col3" >0.658573</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_10b71_row2_col0" class="data row2 col0" >Skl HistGBM</td>
#       <td id="T_10b71_row2_col1" class="data row2 col1" >81.005587</td>
#       <td id="T_10b71_row2_col2" class="data row2 col2" >78.603426</td>
#       <td id="T_10b71_row2_col3" class="data row2 col3" >3.053676</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_10b71_row3_col0" class="data row3 col0" >LightGBM</td>
#       <td id="T_10b71_row3_col1" class="data row3 col1" >81.005587</td>
#       <td id="T_10b71_row3_col2" class="data row3 col2" >78.333333</td>
#       <td id="T_10b71_row3_col3" class="data row3 col3" >0.870609</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_10b71_row4_col0" class="data row4 col0" >AdaBoost</td>
#       <td id="T_10b71_row4_col1" class="data row4 col1" >79.888268</td>
#       <td id="T_10b71_row4_col2" class="data row4 col2" >77.964427</td>
#       <td id="T_10b71_row4_col3" class="data row4 col3" >0.807148</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_10b71_row5_col0" class="data row5 col0" >Random Forest</td>
#       <td id="T_10b71_row5_col1" class="data row5 col1" >79.329609</td>
#       <td id="T_10b71_row5_col2" class="data row5 col2" >76.969697</td>
#       <td id="T_10b71_row5_col3" class="data row5 col3" >1.000699</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_10b71_row6_col0" class="data row6 col0" >CatBoost</td>
#       <td id="T_10b71_row6_col1" class="data row6 col1" >79.329609</td>
#       <td id="T_10b71_row6_col2" class="data row6 col2" >76.969697</td>
#       <td id="T_10b71_row6_col3" class="data row6 col3" >13.586568</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_10b71_row7_col0" class="data row7 col0" >Decision Tree</td>
#       <td id="T_10b71_row7_col1" class="data row7 col1" >77.094972</td>
#       <td id="T_10b71_row7_col2" class="data row7 col2" >75.421607</td>
#       <td id="T_10b71_row7_col3" class="data row7 col3" >0.212057</td>
#     </tr>
#     <tr>
#       <th id="T_10b71_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_10b71_row8_col0" class="data row8 col0" >Extra Trees</td>
#       <td id="T_10b71_row8_col1" class="data row8 col1" >75.977654</td>
#       <td id="T_10b71_row8_col2" class="data row8 col2" >73.432148</td>
#       <td id="T_10b71_row8_col3" class="data row8 col3" >0.693111</td>
#     </tr>
#   </tbody>
# </table>

# %%
assert results_ord["Accuracy"].min() > 75
assert results_ord["Bal Acc."].min() > 73
assert len(results_ord) == 9

# %% [markdown]
# # Exercise 6 (3pts):
# Define a 10 Fold cross validation strategy with:
# - With stratification
# - shuffle=True
# - random_state=0
#
# And train all the models in a for loop.
#
# Tip you can use **[cross_val_predict](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_predict.html)** for both training and predict with

# %%
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})


for model_name, model in tree_classifiers.items():
    start_time = time.time()
        
    # TRAIN AND GET PREDICTIONS USING cross_val_predict() and x,y
    pred = model.predict(x_val)

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)


results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# <style type="text/css">
# #T_05291_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 84.9%, transparent 84.9%);
# }
# #T_05291_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.6%, transparent 82.6%);
# }
# #T_05291_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.6%, transparent 81.6%);
# }
# #T_05291_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
# }
# #T_05291_row2_col1, #T_05291_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.0%, transparent 81.0%);
# }
# #T_05291_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.6%, transparent 78.6%);
# }
# #T_05291_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.3%, transparent 78.3%);
# }
# #T_05291_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
# }
# #T_05291_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.0%, transparent 78.0%);
# }
# #T_05291_row5_col1, #T_05291_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.3%, transparent 79.3%);
# }
# #T_05291_row5_col2, #T_05291_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.0%, transparent 77.0%);
# }
# #T_05291_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.1%, transparent 77.1%);
# }
# #T_05291_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 75.4%, transparent 75.4%);
# }
# #T_05291_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 76.0%, transparent 76.0%);
# }
# #T_05291_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 73.4%, transparent 73.4%);
# }
# </style>
# <table id="T_05291_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05291_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_05291_row0_col0" class="data row0 col0" >Skl GBM</td>
#       <td id="T_05291_row0_col1" class="data row0 col1" >84.916201</td>
#       <td id="T_05291_row0_col2" class="data row0 col2" >82.595520</td>
#       <td id="T_05291_row0_col3" class="data row0 col3" >0.015785</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_05291_row1_col0" class="data row1 col0" >XGBoost</td>
#       <td id="T_05291_row1_col1" class="data row1 col1" >81.564246</td>
#       <td id="T_05291_row1_col2" class="data row1 col2" >78.787879</td>
#       <td id="T_05291_row1_col3" class="data row1 col3" >0.022921</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_05291_row2_col0" class="data row2 col0" >Skl HistGBM</td>
#       <td id="T_05291_row2_col1" class="data row2 col1" >81.005587</td>
#       <td id="T_05291_row2_col2" class="data row2 col2" >78.603426</td>
#       <td id="T_05291_row2_col3" class="data row2 col3" >0.019246</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_05291_row3_col0" class="data row3 col0" >LightGBM</td>
#       <td id="T_05291_row3_col1" class="data row3 col1" >81.005587</td>
#       <td id="T_05291_row3_col2" class="data row3 col2" >78.333333</td>
#       <td id="T_05291_row3_col3" class="data row3 col3" >0.017948</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_05291_row4_col0" class="data row4 col0" >AdaBoost</td>
#       <td id="T_05291_row4_col1" class="data row4 col1" >79.888268</td>
#       <td id="T_05291_row4_col2" class="data row4 col2" >77.964427</td>
#       <td id="T_05291_row4_col3" class="data row4 col3" >0.036131</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_05291_row5_col0" class="data row5 col0" >Random Forest</td>
#       <td id="T_05291_row5_col1" class="data row5 col1" >79.329609</td>
#       <td id="T_05291_row5_col2" class="data row5 col2" >76.969697</td>
#       <td id="T_05291_row5_col3" class="data row5 col3" >0.034658</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_05291_row6_col0" class="data row6 col0" >CatBoost</td>
#       <td id="T_05291_row6_col1" class="data row6 col1" >79.329609</td>
#       <td id="T_05291_row6_col2" class="data row6 col2" >76.969697</td>
#       <td id="T_05291_row6_col3" class="data row6 col3" >0.004066</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_05291_row7_col0" class="data row7 col0" >Decision Tree</td>
#       <td id="T_05291_row7_col1" class="data row7 col1" >77.094972</td>
#       <td id="T_05291_row7_col2" class="data row7 col2" >75.421607</td>
#       <td id="T_05291_row7_col3" class="data row7 col3" >0.013253</td>
#     </tr>
#     <tr>
#       <th id="T_05291_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_05291_row8_col0" class="data row8 col0" >Extra Trees</td>
#       <td id="T_05291_row8_col1" class="data row8 col1" >75.977654</td>
#       <td id="T_05291_row8_col2" class="data row8 col2" >73.432148</td>
#       <td id="T_05291_row8_col3" class="data row8 col3" >0.038775</td>
#     </tr>
#   </tbody>
# </table>

# %%
assert results_ord["Accuracy"].min() > 75
assert results_ord["Bal Acc."].min() > 72
assert len(results_ord) == 9

# %% [markdown]
# # Exercise 7.1
# Train with all data the best model

# %%
best_model = tree_classifiers["Skl GBM"]
best_model.fit(x, y)

# Fit best model with all data
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simple',
#                                                                    SimpleImputer())]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('simple',
#                                                                    SimpleImputer(strategy='constant')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %% [markdown]
# # Exercise 7.2 (2pts)
# With your best model, generate the predicitions for test data (x_test)

# %%
test_pred = best_model.predict(x_test) # Get the predictions for x_test

# %%
assert len(test_pred) == 418
assert np.unique(test_pred).tolist() == [0,1]

# %% [markdown]
# # Exercise 7.3
#
# Submit to kaggle.
#
# - You can use the kaggle command line app. Check https://github.com/Kaggle/kaggle-api

# %%
sub = pd.DataFrame(test_pred, index=x_test.index, columns=["Survived"])
sub.head()
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 0
# 896                 1

# %%
sub.to_csv("sub.csv")

# %%
# !kaggle competitions submit -c titanic -f sub.csv -m "My submission message"
